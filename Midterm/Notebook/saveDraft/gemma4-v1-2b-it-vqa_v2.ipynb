# %% [markdown]
# # Gemma-4 Medical Vision-Language VQA Fine-Tuning with Unsloth
#
# Notebook này hướng dẫn tinh chỉnh (fine-tune) mô hình ngôn ngữ hình ảnh **Gemma-4 E2B/E4B** trên tập dữ liệu **VQA-RAD** để thực hiện tác vụ Medical Visual Question Answering (VQA).
# Hệ thống tích hợp giám sát tự động bằng **Comet ML**, thông báo tiến trình huấn luyện thời gian thực thông qua **Discord Webhook** và đăng nhập **Hugging Face** để lưu trữ model online.
#
# *   **Mô hình mặc định:** `unsloth/gemma-4-E2B-it` (có cấu hình sẵn cho `unsloth/gemma-4-E4B-it` ở dạng comment/ẩn đi).
# *   **Tập dữ liệu:** `flaviagiammarino/vqa-rad` (2,248 QA pairs, 315 radiology images).
# *   **Cơ chế checkpoint:** Lưu vết checkpoint định kỳ, cho phép tiếp tục huấn luyện (resume) từ checkpoint gần nhất nếu bị ngắt quãng.
# *   **Công nghệ tối ưu:** Unsloth & SFTTrainer giúp giảm VRAM cực thấp.

# %%
# %%capture
import os, re
# Cài đặt thư viện Unsloth cùng các dependency cần thiết
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth  # Chạy local hoặc các dịch vụ đám mây khác
else:
    import torch; v = re.match(r'[\d]{1,}\.[\d]{1,}', str(torch.__version__)).group(0)
    xformers = 'xformers==' + {'2.10':'0.0.34','2.9':'0.0.33.post1','2.8':'0.0.32.post2'}.get(v, "0.0.34")
    # !pip install sentencepiece protobuf "datasets==4.3.0" "huggingface_hub>=0.34.0" hf_transfer
    # !pip install --no-deps unsloth_zoo bitsandbytes accelerate {xformers} peft trl triton unsloth
    # !pip install --no-deps --upgrade "torchao>=0.16.0"
# !pip install --no-deps transformers==5.5.0 "tokenizers>=0.22.0,<=0.23.0"
# !pip install torchcodec
# !pip install --no-deps --upgrade timm
# !pip install comet-ml requests pillow python-dotenv

# %%
# !pip install opik
# Out:
# Collecting opik
#   Downloading opik-2.0.68-py3-none-any.whl.metadata (35 kB)
# Collecting boto3-stubs>=1.34.110 (from boto3-stubs[bedrock-runtime]>=1.34.110->opik)
#   Downloading boto3_stubs-1.43.32-py3-none-any.whl.metadata (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.6/156.6 kB 4.1 MB/s eta 0:00:0000:01
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from opik) (8.3.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from opik) (0.28.1)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from opik)
#   Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Collecting litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2 (from opik)
#   Downloading litellm-1.89.2-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (from opik) (2.31.0)
# Requirement already satisfied: pydantic-settings!=2.9.0,<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from opik) (2.13.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from opik) (2.12.3)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from opik) (8.4.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from opik) (13.9.4)
# Requirement already satisfied: sentry_sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from opik) (2.57.0)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from opik) (9.1.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from opik) (4.67.3)
# Collecting uuid6 (from opik)
#   Downloading uuid6-2025.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from opik) (3.1.6)
# Requirement already satisfied: watchfiles<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from opik) (1.1.1)
# Collecting tree-sitter<1.0,>=0.23 (from opik)
#   Downloading tree_sitter-0.25.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10.0 kB)
# Collecting tree-sitter-javascript<1.0,>=0.23 (from opik)
#   Downloading tree_sitter_javascript-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (2.2 kB)
# Collecting tree-sitter-typescript<1.0,>=0.23 (from opik)
#   Downloading tree_sitter_typescript-0.23.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting botocore-stubs (from boto3-stubs>=1.34.110->boto3-stubs[bedrock-runtime]>=1.34.110->opik)
#   Downloading botocore_stubs-1.43.14-py3-none-any.whl.metadata (3.4 kB)
# Collecting types-s3transfer (from boto3-stubs>=1.34.110->boto3-stubs[bedrock-runtime]>=1.34.110->opik)
#   Downloading types_s3transfer-0.16.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting mypy-boto3-bedrock-runtime<1.44.0,>=1.43.0 (from boto3-stubs[bedrock-runtime]>=1.34.110->opik)
#   Downloading mypy_boto3_bedrock_runtime-1.43.30-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: fastuuid<1.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (0.14.0)
# Requirement already satisfied: python-dotenv<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (1.2.2)
# Requirement already satisfied: tiktoken<1.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (0.12.0)
# Requirement already satisfied: importlib-metadata<9.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (8.7.1)
# Requirement already satisfied: tokenizers<1.0,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (0.22.2)
# Requirement already satisfied: aiohttp<4.0,>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (3.13.5)
# Requirement already satisfied: jsonschema<5.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (4.26.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->opik) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx->opik) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->opik) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->opik) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->opik) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->opik) (3.0.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai->opik) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai->opik) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai->opik) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai->opik) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->opik) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->opik) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->opik) (0.4.2)
# Requirement already satisfied: urllib3>=1.26.11 in /usr/local/lib/python3.12/dist-packages (from sentry_sdk>=2.0.0->opik) (2.5.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->opik) (2.3.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from pytest->opik) (26.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->opik) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest->opik) (2.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->opik) (4.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (1.23.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9.0,>=8.0.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (0.30.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->opik) (0.1.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0,>=0.8.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0,>=0.8.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (2.32.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers<1.0,>=0.21.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (1.10.1)
# Collecting types-awscrt (from botocore-stubs->boto3-stubs>=1.34.110->boto3-stubs[bedrock-runtime]>=1.34.110->opik)
#   Downloading types_awscrt-0.34.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (1.4.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (6.0.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (0.24.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0,>=0.8.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (3.4.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik) (0.0.4)
# Downloading opik-2.0.68-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.9 MB/s eta 0:00:00a 0:00:01
# Downloading boto3_stubs-1.43.32-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 5.3 MB/s eta 0:00:00
# Downloading litellm-1.89.2-py3-none-any.whl (15.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 94.4 MB/s eta 0:00:00:00:0100:01
# Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 87.2 MB/s eta 0:00:00:00:01
# Downloading tree_sitter-0.25.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (635 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.4/635.4 kB 40.3 MB/s eta 0:00:00
# Downloading tree_sitter_javascript-0.25.0-cp310-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 8.6 MB/s eta 0:00:00
# Downloading tree_sitter_typescript-0.23.2-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (344 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.0/345.0 kB 24.7 MB/s eta 0:00:00
# Downloading uuid6-2025.0.1-py3-none-any.whl (7.0 kB)
# Downloading mypy_boto3_bedrock_runtime-1.43.30-py3-none-any.whl (37 kB)
# Downloading botocore_stubs-1.43.14-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 5.9 MB/s eta 0:00:00
# Downloading types_s3transfer-0.16.0-py3-none-any.whl (19 kB)
# Downloading types_awscrt-0.34.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: uuid6, types-s3transfer, types-awscrt, tree-sitter-typescript, tree-sitter-javascript, tree-sitter, rapidfuzz, mypy-boto3-bedrock-runtime, botocore-stubs, boto3-stubs, litellm, opik
#   Attempting uninstall: litellm
#     Found existing installation: litellm 1.82.4
#     Uninstalling litellm-1.82.4:
#       Successfully uninstalled litellm-1.82.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.29.3 requires litellm<=1.82.4, but you have litellm 1.89.2 which is incompatible.
# Successfully installed boto3-stubs-1.43.32 botocore-stubs-1.43.14 litellm-1.89.2 mypy-boto3-bedrock-runtime-1.43.30 opik-2.0.68 rapidfuzz-3.14.5 tree-sitter-0.25.2 tree-sitter-javascript-0.25.0 tree-sitter-typescript-0.23.2 types-awscrt-0.34.1 types-s3transfer-0.16.0 uuid6-2025.0.1

# %%
import comet_ml  # Must be first import
import os
from huggingface_hub import login

# 1. Load API keys from Kaggle Secrets or .env fallback
try:
    from kaggle_secrets import UserSecretsClient
    user_secrets = UserSecretsClient()
    os.environ["COMET_API_KEY"] = user_secrets.get_secret("COMET_API_KEY")
    DISCORD_WEBHOOK_URL = user_secrets.get_secret("DISCORD_WEBHOOK_URL")
    os.environ["HF_TOKEN"] = user_secrets.get_secret("HF_TOKEN")
    print("🔑 Đã nạp thành công API Key, Webhook & HF Token từ Kaggle Secrets!")

except Exception as e:
    try:
        from dotenv import load_dotenv
        load_dotenv()  # Automatically populates os.environ from .env file
        DISCORD_WEBHOOK_URL = os.environ.get("DISCORD_WEBHOOK_URL")
        print("🔑 Đã nạp thành công cấu hình từ file .env!")

    except Exception:
        os.environ["COMET_API_KEY"] = "YOUR_COMET_API_KEY"
        DISCORD_WEBHOOK_URL = "YOUR_DISCORD_WEBHOOK_URL"
        os.environ["HF_TOKEN"] = "YOUR_HF_TOKEN"
        print("⚠️ Vui lòng điền API Key thủ công trong code.")

# 2. Login to Hugging Face Hub
hf_token = os.environ.get("HF_TOKEN")
if hf_token and hf_token != "YOUR_HF_TOKEN" and hf_token.strip() != "":
    login(token=hf_token)
    print("🤗 Đăng nhập Hugging Face Hub thành công!")
else:
    print("⚠️ Thiếu HF_TOKEN. Không thể push model lên Hugging Face Hub.")

# 3. Initialize Comet ML Experiment
os.environ["COMET_PROJECT_NAME"] = "gemma4-medical-vqa"

experiment = comet_ml.Experiment(
    project_name="gemma4-medical-vqa",
    auto_metric_logging=True,
    auto_param_logging=True,
    auto_histogram_logging=True,
)
print("☄️ Comet ML Experiment đã được thiết lập thành công!")
# Out:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : magnificent_thrush_6957
# COMET INFO:     url                   : https://www.comet.com/ho-ng-v-7034/gemma4-medical-vqa/7aa30b6081bd49a7bf6e554605ba8b24
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     train/epoch [13]         : (0.022308979364194088, 0.29001673173452314)
# COMET INFO:     train/grad_norm [13]     : (0.5074192881584167, 8.05798625946045)
# COMET INFO:     train/learning_rate [13] : (0.00016490471383605288, 0.0001999777729859618)
# COMET INFO:     train/loss [13]          : (0.3578755855560303, 3.8334781646728517)
# COMET INFO:   Others:
# COMET INFO:     hasNestedParams : True
# COMET INFO:   Parameters:
# COMET INFO:     args|accelerator_config|dispatch_batches                                : None
# COMET INFO:     args|accelerator_config|even_batches                                    : True
# COMET INFO:     args|accelerator_config|gradient_accumulation_kwargs                    : None
# COMET INFO:     args|accelerator_config|non_blocking                                    : False
# COMET INFO:     args|accelerator_config|split_batches                                   : False
# COMET INFO:     args|accelerator_config|use_seedable_sampler                            : True
# COMET INFO:     args|activation_offloading                                              : False
# COMET INFO:     args|adam_beta1                                                         : 0.9
# COMET INFO:     args|adam_beta2                                                         : 0.999
# COMET INFO:     args|adam_epsilon                                                       : 1e-08
# COMET INFO:     args|assistant_only_loss                                                : False
# COMET INFO:     args|auto_find_batch_size                                               : False
# COMET INFO:     args|average_tokens_across_devices                                      : True
# COMET INFO:     args|batch_eval_metrics                                                 : False
# COMET INFO:     args|bf16                                                               : False
# COMET INFO:     args|bf16_full_eval                                                     : False
# COMET INFO:     args|chat_template_path                                                 : None
# COMET INFO:     args|completion_only_loss                                               : None
# COMET INFO:     args|data_seed                                                          : 3407
# COMET INFO:     args|dataloader_drop_last                                               : False
# COMET INFO:     args|dataloader_num_workers                                             : 0
# COMET INFO:     args|dataloader_persistent_workers                                      : False
# COMET INFO:     args|dataloader_pin_memory                                              : True
# COMET INFO:     args|dataloader_prefetch_factor                                         : None
# COMET INFO:     args|dataset_kwargs|skip_prepare_dataset                                : True
# COMET INFO:     args|dataset_num_proc                                                   : 8
# COMET INFO:     args|dataset_text_field                                                 :
# COMET INFO:     args|ddp_backend                                                        : None
# COMET INFO:     args|ddp_broadcast_buffers                                              : None
# COMET INFO:     args|ddp_bucket_cap_mb                                                  : None
# COMET INFO:     args|ddp_find_unused_parameters                                         : None
# COMET INFO:     args|ddp_timeout                                                        : 1800
# COMET INFO:     args|debug                                                              : []
# COMET INFO:     args|deepspeed                                                          : None
# COMET INFO:     args|disable_tqdm                                                       : False
# COMET INFO:     args|do_eval                                                            : False
# COMET INFO:     args|do_predict                                                         : False
# COMET INFO:     args|do_train                                                           : False
# COMET INFO:     args|enable_jit_checkpoint                                              : False
# COMET INFO:     args|eos_token                                                          : <EOS_TOKEN>
# COMET INFO:     args|eval_accumulation_steps                                            : 2
# COMET INFO:     args|eval_delay                                                         : 0
# COMET INFO:     args|eval_do_concat_batches                                             : True
# COMET INFO:     args|eval_on_start                                                      : False
# COMET INFO:     args|eval_packing                                                       : None
# COMET INFO:     args|eval_steps                                                         : None
# COMET INFO:     args|eval_strategy                                                      : no
# 🔑 Đã nạp thành công API Key, Webhook & HF Token từ Kaggle Secrets!
# 🤗 Đăng nhập Hugging Face Hub thành công!
# COMET INFO:     args|eval_use_gather_object                                             : False
# COMET INFO:     args|fp16                                                               : True
# COMET INFO:     args|fp16_full_eval                                                     : True
# COMET INFO:     args|fsdp                                                               : []
# COMET INFO:     args|fsdp_config|min_num_params                                         : 0
# COMET INFO:     args|fsdp_config|xla                                                    : False
# COMET INFO:     args|fsdp_config|xla_fsdp_grad_ckpt                                     : False
# COMET INFO:     args|fsdp_config|xla_fsdp_v2                                            : False
# COMET INFO:     args|full_determinism                                                   : False
# COMET INFO:     args|gradient_accumulation_steps                                        : 4
# COMET INFO:     args|gradient_checkpointing                                             : True
# COMET INFO:     args|gradient_checkpointing_kwargs                                      : None
# COMET INFO:     args|greater_is_better                                                  : None
# COMET INFO:     args|hub_always_push                                                    : False
# COMET INFO:     args|hub_model_id                                                       : HoangVuSnape/gemma_4_lora
# COMET INFO:     args|hub_private_repo                                                   : None
# COMET INFO:     args|hub_revision                                                       : None
# COMET INFO:     args|hub_strategy                                                       : checkpoint
# COMET INFO:     args|hub_token                                                          : <HUB_TOKEN>
# COMET INFO:     args|ignore_data_skip                                                   : False
# COMET INFO:     args|include_for_metrics                                                : []
# COMET INFO:     args|include_num_input_tokens_seen                                      : no
# COMET INFO:     args|label_names                                                        : None
# COMET INFO:     args|label_smoothing_factor                                             : 0.0
# COMET INFO:     args|learning_rate                                                      : 0.0002
# COMET INFO:     args|length_column_name                                                 : length
# COMET INFO:     args|liger_kernel_config                                                : None
# COMET INFO:     args|load_best_model_at_end                                             : False
# COMET INFO:     args|local_rank                                                         : -1
# COMET INFO:     args|log_level                                                          : passive
# COMET INFO:     args|log_level_replica                                                  : warning
# COMET INFO:     args|log_on_each_node                                                   : True
# COMET INFO:     args|logging_dir                                                        : None
# COMET INFO:     args|logging_first_step                                                 : False
# COMET INFO:     args|logging_nan_inf_filter                                             : False
# COMET INFO:     args|logging_steps                                                      : 10
# COMET INFO:     args|logging_strategy                                                   : steps
# COMET INFO:     args|loss_type                                                          : nll
# COMET INFO:     args|lr_scheduler_kwargs                                                : None
# COMET INFO:     args|lr_scheduler_type                                                  : cosine
# COMET INFO:     args|max_grad_norm                                                      : 0.3
# COMET INFO:     args|max_length                                                         : 2048
# COMET INFO:     args|max_seq_length                                                     : 2048
# COMET INFO:     args|max_steps                                                          : -1
# COMET INFO:     args|metric_for_best_model                                              : None
# COMET INFO:     args|model_init_kwargs                                                  : None
# COMET INFO:     args|neftune_noise_alpha                                                : None
# COMET INFO:     args|num_train_epochs                                                   : 1
# COMET INFO:     args|optim                                                              : adamw_8bit
# COMET INFO:     args|optim_args                                                         : None
# COMET INFO:     args|optim_target_modules                                               : None
# COMET INFO:     args|output_dir                                                         : gemma_4_lora_project
# COMET INFO:     args|packing                                                            : False
# COMET INFO:     args|packing_strategy                                                   : bfd
# COMET INFO:     args|pad_to_multiple_of                                                 : None
# COMET INFO:     args|pad_token                                                          : <PAD_TOKEN>
# COMET INFO:     args|padding_free                                                       : False
# COMET INFO:     args|parallelism_config                                                 : None
# COMET INFO:     args|per_device_eval_batch_size                                         : 4
# COMET INFO:     args|per_device_train_batch_size                                        : 1
# COMET INFO:     args|prediction_loss_only                                               : False
# COMET INFO:     args|project                                                            : huggingface
# COMET INFO:     args|push_to_hub                                                        : True
# COMET INFO:     args|push_to_hub_token                                                  : None
# COMET INFO:     args|remove_unused_columns                                              : False
# COMET INFO:     args|report_to                                                          : ['comet_ml']
# COMET INFO:     args|restore_callback_states_from_checkpoint                            : False
# COMET INFO:     args|resume_from_checkpoint                                             : None
# COMET INFO:     args|run_name                                                           : None
# COMET INFO:     args|save_on_each_node                                                  : False
# COMET INFO:     args|save_only_model                                                    : False
# COMET INFO:     args|save_steps                                                         : 50
# COMET INFO:     args|save_strategy                                                      : steps
# COMET INFO:     args|save_total_limit                                                   : 2
# COMET INFO:     args|seed                                                               : 3407
# COMET INFO:     args|shuffle_dataset                                                    : False
# COMET INFO:     args|skip_memory_metrics                                                : True
# COMET INFO:     args|tf32                                                               : None
# COMET INFO:     args|torch_compile                                                      : False
# COMET INFO:     args|torch_compile_backend                                              : None
# COMET INFO:     args|torch_compile_mode                                                 : None
# COMET INFO:     args|torch_empty_cache_steps                                            : 250
# COMET INFO:     args|trackio_space_id                                                   : trackio
# COMET INFO:     args|train_sampling_strategy                                            : random
# COMET INFO:     args|truncation_mode                                                    : keep_start
# COMET INFO:     args|unsloth_grpo_mini_batch                                            : None
# COMET INFO:     args|unsloth_logit_chunk_multiplier                                     : None
# COMET INFO:     args|unsloth_num_chunks                                                 : -1
# COMET INFO:     args|use_cache                                                          : False
# COMET INFO:     args|use_cpu                                                            : False
# COMET INFO:     args|use_liger_kernel                                                   : False
# COMET INFO:     args|vllm_sampling_params                                               : None
# COMET INFO:     args|warmup_ratio                                                       : None
# COMET INFO:     args|warmup_steps                                                       : 2
# COMET INFO:     args|weight_decay                                                       : 0.001
# COMET INFO:     config|_name_or_path                                                    : unsloth/gemma-4-e2b-it-unsloth-bnb-4bit
# COMET INFO:     config|architectures                                                    : ['Gemma4ForConditionalGeneration']
# COMET INFO:     config|audio_config|_name_or_path                                       :
# COMET INFO:     config|audio_config|architectures                                       : None
# COMET INFO:     config|audio_config|attention_chunk_size                                : 12
# COMET INFO:     config|audio_config|attention_context_left                              : 13
# COMET INFO:     config|audio_config|attention_context_right                             : 0
# COMET INFO:     config|audio_config|attention_invalid_logits_value                      : -1000000000.0
# COMET INFO:     config|audio_config|attention_logit_cap                                 : 50.0
# COMET INFO:     config|audio_config|chunk_size_feed_forward                             : 0
# COMET INFO:     config|audio_config|conv_kernel_size                                    : 5
# COMET INFO:     config|audio_config|dtype                                               : float16
# COMET INFO:     config|audio_config|gradient_clipping                                   : 10000000000.0
# COMET INFO:     config|audio_config|hidden_act                                          : silu
# COMET INFO:     config|audio_config|hidden_size                                         : 1024
# COMET INFO:     config|audio_config|id2label|0                                          : LABEL_0
# COMET INFO:     config|audio_config|id2label|1                                          : LABEL_1
# COMET INFO:     config|audio_config|initializer_range                                   : 0.02
# COMET INFO:     config|audio_config|is_encoder_decoder                                  : False
# COMET INFO:     config|audio_config|label2id|LABEL_0                                    : 0
# COMET INFO:     config|audio_config|label2id|LABEL_1                                    : 1
# COMET INFO:     config|audio_config|model_type                                          : gemma4_audio
# COMET INFO:     config|audio_config|num_attention_heads                                 : 8
# COMET INFO:     config|audio_config|num_hidden_layers                                   : 12
# COMET INFO:     config|audio_config|output_attentions                                   : False
# COMET INFO:     config|audio_config|output_hidden_states                                : False
# COMET INFO:     config|audio_config|output_proj_dims                                    : 1536
# COMET INFO:     config|audio_config|problem_type                                        : None
# COMET INFO:     config|audio_config|residual_weight                                     : 0.5
# COMET INFO:     config|audio_config|return_dict                                         : True
# COMET INFO:     config|audio_config|rms_norm_eps                                        : 1e-06
# COMET INFO:     config|audio_config|subsampling_conv_channels                           : [128, 32]
# COMET INFO:     config|audio_config|use_clipped_linears                                 : True
# COMET INFO:     config|audio_token_id                                                   : 258881
# COMET INFO:     config|boa_token_id                                                     : 256000
# COMET INFO:     config|boi_token_id                                                     : 255999
# COMET INFO:     config|bos_token_id                                                     : 2
# COMET INFO:     config|chunk_size_feed_forward                                          : 0
# COMET INFO:     config|dtype                                                            : float16
# COMET INFO:     config|eoa_token_id                                                     : 258883
# COMET INFO:     config|eoa_token_index                                                  : 258883
# COMET INFO:     config|eoi_token_id                                                     : 258882
# COMET INFO:     config|eos_token_id                                                     : 1
# COMET INFO:     config|id2label|0                                                       : LABEL_0
# COMET INFO:     config|id2label|1                                                       : LABEL_1
# COMET INFO:     config|image_token_id                                                   : 258880
# COMET INFO:     config|initializer_range                                                : 0.02
# COMET INFO:     config|is_encoder_decoder                                               : False
# COMET INFO:     config|label2id|LABEL_0                                                 : 0
# COMET INFO:     config|label2id|LABEL_1                                                 : 1
# COMET INFO:     config|model_name                                                       : unsloth/gemma-4-e2b-it-unsloth-bnb-4bit
# COMET INFO:     config|model_type                                                       : gemma4
# COMET INFO:     config|output_attentions                                                : False
# COMET INFO:     config|output_hidden_states                                             : False
# COMET INFO:     config|pad_token_id                                                     : 0
# COMET INFO:     config|problem_type                                                     : None
# COMET INFO:     config|quantization_config|bnb_4bit_compute_dtype                       : float16
# COMET INFO:     config|quantization_config|bnb_4bit_quant_type                          : nf4
# COMET INFO:     config|quantization_config|bnb_4bit_use_double_quant                    : True
# COMET INFO:     config|quantization_config|llm_int8_enable_fp32_cpu_offload             : False
# COMET INFO:     config|quantization_config|llm_int8_has_fp16_weight                     : False
# COMET INFO:     config|quantization_config|llm_int8_skip_modules                        : None
# COMET INFO:     config|quantization_config|llm_int8_threshold                           : 6.0
# COMET INFO:     config|quantization_config|load_in_4bit                                 : True
# COMET INFO:     config|quantization_config|load_in_8bit                                 : False
# COMET INFO:     config|quantization_config|quant_method                                 : bitsandbytes
# COMET INFO:     config|return_dict                                                      : True
# COMET INFO:     config|text_config|_name_or_path                                        :
# COMET INFO:     config|text_config|architectures                                        : None
# COMET INFO:     config|text_config|attention_bias                                       : False
# COMET INFO:     config|text_config|attention_dropout                                    : 0.0
# COMET INFO:     config|text_config|attention_k_eq_v                                     : False
# COMET INFO:     config|text_config|bos_token_id                                         : 2
# COMET INFO:     config|text_config|chunk_size_feed_forward                              : 0
# COMET INFO:     config|text_config|dtype                                                : float16
# COMET INFO:     config|text_config|enable_moe_block                                     : False
# COMET INFO:     config|text_config|eos_token_id                                         : 1
# COMET INFO:     config|text_config|expert_intermediate_size                             : None
# COMET INFO:     config|text_config|final_logit_softcapping                              : 30.0
# COMET INFO:     config|text_config|global_head_dim                                      : 512
# COMET INFO:     config|text_config|head_dim                                             : 256
# COMET INFO:     config|text_config|hidden_activation                                    : gelu_pytorch_tanh
# COMET INFO:     config|text_config|hidden_size                                          : 1536
# COMET INFO:     config|text_config|hidden_size_per_layer_input                          : 256
# COMET INFO:     config|text_config|id2label|0                                           : LABEL_0
# COMET INFO:     config|text_config|id2label|1                                           : LABEL_1
# COMET INFO:     config|text_config|initializer_range                                    : 0.02
# COMET INFO:     config|text_config|intermediate_size                                    : 6144
# COMET INFO:     config|text_config|is_encoder_decoder                                   : False
# COMET INFO:     config|text_config|label2id|LABEL_0                                     : 0
# COMET INFO:     config|text_config|label2id|LABEL_1                                     : 1
# COMET INFO:     config|text_config|layer_types                                          : ['sliding_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'full_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'full_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'full_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'full_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'full_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'full_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'sliding_attention', 'full_attention']
# COMET INFO:     config|text_config|max_position_embeddings                              : 131072
# COMET INFO:     config|text_config|model_type                                           : gemma4_text
# COMET INFO:     config|text_config|moe_intermediate_size                                : None
# COMET INFO:     config|text_config|num_attention_heads                                  : 8
# COMET INFO:     config|text_config|num_experts                                          : None
# COMET INFO:     config|text_config|num_global_key_value_heads                           : None
# COMET INFO:     config|text_config|num_hidden_layers                                    : 35
# COMET INFO:     config|text_config|num_key_value_heads                                  : 1
# COMET INFO:     config|text_config|num_kv_shared_layers                                 : 20
# COMET INFO:     config|text_config|output_attentions                                    : False
# COMET INFO:     config|text_config|output_hidden_states                                 : False
# COMET INFO:     config|text_config|pad_token_id                                         : 0
# COMET INFO:     config|text_config|problem_type                                         : None
# COMET INFO:     config|text_config|return_dict                                          : True
# COMET INFO:     config|text_config|rms_norm_eps                                         : 1e-06
# COMET INFO:     config|text_config|rope_parameters|full_attention|partial_rotary_factor : 0.25
# COMET INFO:     config|text_config|rope_parameters|full_attention|rope_theta            : 1000000.0
# COMET INFO:     config|text_config|rope_parameters|full_attention|rope_type             : proportional
# COMET INFO:     config|text_config|rope_parameters|sliding_attention|rope_theta         : 10000.0
# COMET INFO:     config|text_config|rope_parameters|sliding_attention|rope_type          : default
# COMET INFO:     config|text_config|sliding_window                                       : 512
# COMET INFO:     config|text_config|tie_word_embeddings                                  : True
# COMET INFO:     config|text_config|top_k_experts                                        : None
# COMET INFO:     config|text_config|use_bidirectional_attention                          : None
# COMET INFO:     config|text_config|use_cache                                            : False
# COMET INFO:     config|text_config|use_double_wide_mlp                                  : True
# COMET INFO:     config|text_config|vocab_size                                           : 262144
# COMET INFO:     config|text_config|vocab_size_per_layer_input                           : 262144
# COMET INFO:     config|tie_word_embeddings                                              : True
# COMET INFO:     config|transformers_version                                             : 5.5.0
# COMET INFO:     config|unsloth_fixed                                                    : True
# COMET INFO:     config|unsloth_version                                                  : 2026.6.7
# COMET INFO:     config|use_cache                                                        : False
# COMET INFO:     config|video_token_id                                                   : 258884
# COMET INFO:     config|vision_config|_name_or_path                                      :
# COMET INFO:     config|vision_config|architectures                                      : None
# COMET INFO:     config|vision_config|attention_bias                                     : False
# COMET INFO:     config|vision_config|attention_dropout                                  : 0.0
# COMET INFO:     config|vision_config|chunk_size_feed_forward                            : 0
# COMET INFO:     config|vision_config|default_output_length                              : 280
# COMET INFO:     config|vision_config|dtype                                              : float16
# COMET INFO:     config|vision_config|global_head_dim                                    : 64
# COMET INFO:     config|vision_config|head_dim                                           : 64
# COMET INFO:     config|vision_config|hidden_activation                                  : gelu_pytorch_tanh
# COMET INFO:     config|vision_config|hidden_size                                        : 768
# COMET INFO:     config|vision_config|id2label|0                                         : LABEL_0
# COMET INFO:     config|vision_config|id2label|1                                         : LABEL_1
# COMET INFO:     config|vision_config|initializer_range                                  : 0.02
# COMET INFO:     config|vision_config|intermediate_size                                  : 3072
# COMET INFO:     config|vision_config|is_encoder_decoder                                 : False
# COMET INFO:     config|vision_config|label2id|LABEL_0                                   : 0
# COMET INFO:     config|vision_config|label2id|LABEL_1                                   : 1
# COMET INFO:     config|vision_config|max_position_embeddings                            : 131072
# COMET INFO:     config|vision_config|model_type                                         : gemma4_vision
# COMET INFO:     config|vision_config|num_attention_heads                                : 12
# COMET INFO:     config|vision_config|num_hidden_layers                                  : 16
# COMET INFO:     config|vision_config|num_key_value_heads                                : 12
# COMET INFO:     config|vision_config|output_attentions                                  : False
# COMET INFO:     config|vision_config|output_hidden_states                               : False
# COMET INFO:     config|vision_config|patch_size                                         : 16
# COMET INFO:     config|vision_config|pooling_kernel_size                                : 3
# COMET INFO:     config|vision_config|position_embedding_size                            : 10240
# COMET INFO:     config|vision_config|problem_type                                       : None
# COMET INFO:     config|vision_config|return_dict                                        : True
# COMET INFO:     config|vision_config|rms_norm_eps                                       : 1e-06
# COMET INFO:     config|vision_config|rope_parameters|rope_theta                         : 100.0
# COMET INFO:     config|vision_config|rope_parameters|rope_type                          : default
# COMET INFO:     config|vision_config|standardize                                        : False
# COMET INFO:     config|vision_config|use_clipped_linears                                : True
# COMET INFO:     config|vision_soft_tokens_per_image                                     : 280
# COMET INFO:     peft_config|default                                                     : LoraConfig(task_type=<TaskType.CAUSAL_LM: 'CAUSAL_LM'>, peft_type=<PeftType.LORA: 'LORA'>, auto_mapping={'base_model_class': 'Gemma4ForConditionalGeneration', 'parent_library': 'transformers.models.gemma4.modeling_gemma4', 'unsloth_fixed': True}, peft_version='0.18.1', base_model_name_or_path='unsloth/gemma-4-e2b-it-unsloth-bnb-4bit', revision=None, inference_mode=False, r=16, target_modules='(?:.*?(?:vision|image|visual|patch|language|text).*?(?:self_attn|attention|attn|mlp|feed_forward|ffn|dense).*?(?:k_proj|q_proj|v_proj|o_proj|gate_proj|up_proj|down_proj|per_layer_input_gate|per_layer_projection|linear|embedding_projection|relative_k_proj).*?)|(?:\\bmodel\\.layers\\.[\\d]{1,}\\.(?:self_attn|attention|attn|mlp|feed_forward|ffn|dense)\\.(?:(?:k_proj|q_proj|v_proj|o_proj|gate_proj|up_proj|down_proj|per_layer_input_gate|per_layer_projection|linear|embedding_projection|relative_k_proj)))', exclude_modules=None, lora_alpha=16, lora_dropout=0, fan_in_fan_out=False, bias='none' [truncated]
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ho-ng-v-7034/gemma4-medical-vqa/0a1ba67e84974e318b681b07d69d56bc
# ☄️ Comet ML Experiment đã được thiết lập thành công!
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.

# %%
# Khởi tạo experiment thủ công
experiment = comet_ml.Experiment(
    project_name="gemma4-medical-vqa",
    auto_metric_logging=True,
    auto_param_logging=True,
    auto_histogram_logging=True,
)
# Log thêm thông tin tùy chỉnh
experiment.log_parameter("model_name", "google/gemma-3-4b-it")
experiment.log_parameter("dataset", "medical-vqa-dataset")
experiment.add_tag("fine-tuning")
experiment.add_tag("kaggle")
# Out:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : dull_cod_2089
# COMET INFO:     url                   : https://www.comet.com/ho-ng-v-7034/gemma4-medical-vqa/0a1ba67e84974e318b681b07d69d56bc
# COMET INFO:   Uploads:
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ho-ng-v-7034/gemma4-medical-vqa/c6a221dcc6014e049e94e98501073b27
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.

# %% [markdown]
# ## 1. Tải và Khám phá Dữ liệu (Data Prep & Processing)
#
# Chúng ta tải dữ liệu `flaviagiammarino/vqa-rad` từ Hugging Face. Tập dữ liệu này chứa sẵn các cặp câu hỏi-trả lời y khoa (`question` và `answer`) kèm hình ảnh chẩn đoán X-ray tương ứng, đã được chia sẵn làm tập train và test.

# %%
from datasets import load_dataset

# Tải dataset train và test
train_dataset = load_dataset("flaviagiammarino/vqa-rad", split="train")
test_dataset = load_dataset("flaviagiammarino/vqa-rad", split="test")

print("📊 Thông tin Train dataset:")
print(train_dataset)
print("\n📊 Thông tin Test dataset:")
print(test_dataset)
print(f"\n👉 Tổng số lượng mẫu: Train ({len(train_dataset)}), Test ({len(test_dataset)})")
# Out:
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# 📊 Thông tin Train dataset:
# Dataset({
#     features: ['image', 'question', 'answer'],
#     num_rows: 1793
# })
#
# 📊 Thông tin Test dataset:
# Dataset({
#     features: ['image', 'question', 'answer'],
#     num_rows: 451
# })
#
# 👉 Tổng số lượng mẫu: Train (1793), Test (451)

# %%
# Trực quan mẫu dữ liệu thứ 3 từ tập train
sample_idx = 2
sample = train_dataset[sample_idx]
print(f"🔍 Mẫu train index {sample_idx}:")
print(f"• Câu hỏi (Question): {sample['question']}")
print(f"• Trả lời (Answer): {sample['answer']}")

# Hiển thị hình ảnh X-ray tương ứng
display(sample["image"].resize((300, 300)))
# Out:
# 🔍 Mẫu train index 2:
# • Câu hỏi (Question): which organ system is abnormal in this image?
# • Trả lời (Answer): cardiovascular
# <PIL.Image.Image image mode=RGB size=300x300>

# %% [markdown]
# Mô hình ngôn ngữ hình ảnh (VLM) của Unsloth Gemma-4 yêu cầu dữ liệu chuẩn hóa dạng hội thoại (`messages`). Cấu trúc gồm ảnh và câu hỏi ở role `user`, câu trả lời ở role `assistant`:
# ```python
# [
#     {
#         "role": "user",
#         "content": [
#             {"type": "text", "text": sample["question"]},
#             {"type": "image", "image": sample["image"]}
#         ]
#     },
#     {
#         "role": "assistant",
#         "content": [
#             {"type": "text", "text": sample["answer"]}
#         ]
#     }
# ]
# ```

# %%
def convert_to_conversation(sample):
    conversation = [
        {
            "role": "user",
            "content": [
                {"type": "text", "text": sample["question"]},
                {"type": "image", "image": sample["image"]}
            ]
        },
        {
            "role": "assistant",
            "content": [{"type": "text", "text": sample["answer"]}]
        }
    ]
    return {"messages": conversation}

# Tiến hành ánh xạ toàn bộ tập dữ liệu train và test
converted_train_dataset = [convert_to_conversation(item) for item in train_dataset]
converted_test_dataset = [convert_to_conversation(item) for item in test_dataset]
print(f"✅ Đã xử lý {len(converted_train_dataset)} mẫu train và {len(converted_test_dataset)} mẫu test.")
print("👉 Xem thử mẫu train đầu tiên:")
import pprint
pprint.pprint(converted_train_dataset[0]["messages"])
# Out:
# ✅ Đã xử lý 1793 mẫu train và 451 mẫu test.
# 👉 Xem thử mẫu train đầu tiên:
# [{'content': [{'text': 'are regions of the brain infarcted?', 'type': 'text'},
#               {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=566x555 at 0x79FFF0947920>,
#                'type': 'image'}],
#   'role': 'user'},
#  {'content': [{'text': 'yes', 'type': 'text'}], 'role': 'assistant'}]

# %% [markdown]
# ## 2. Khởi tạo Mô hình Gemma-4 (Model & LoRA Setup)
#
# Chúng ta load model Gemma-4. Theo yêu cầu, mô hình **Gemma-4 E2B** được chạy mặc định, còn mô hình lớn hơn **Gemma-4 E4B** được ẩn đi dưới dạng comment để dễ dàng kích hoạt khi cần.

# %%
from unsloth import FastVisionModel
import torch

# Chọn 1 trong 2 model. Model 4B được ẩn đi (comment out).
model_name = "unsloth/gemma-4-E2B-it"  # Mô hình E2B (2 Tỷ tham số) - Nhẹ, debug nhanh
# model_name = "unsloth/gemma-4-E4B-it"  # Mô hình E4B (4 Tỷ tham số) - Hiệu năng cao hơn

print(f"🚀 Đang tải mô hình từ HuggingFace: {model_name}...")

model, processor = FastVisionModel.from_pretrained(
    model_name,
    load_in_4bit = True,  # Sử dụng định dạng 4bit để siêu tiết kiệm VRAM
    use_gradient_checkpointing = "unsloth",
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🚀 Đang tải mô hình từ HuggingFace: unsloth/gemma-4-E2B-it...
# ==((====))==  Unsloth 2026.6.7: Fast Gemma4 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.562 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.34. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/2011 [00:00<?, ?it/s]

# %%
# Cấu hình LoRA Adapter tiết kiệm tham số (chỉ train ~1.1% tổng trọng số)
model = FastVisionModel.get_peft_model(
    model,
    finetune_vision_layers     = True,  # Fine-tune module hình ảnh (Vision encoder)
    finetune_language_layers   = True,  # Fine-tune module ngôn ngữ (LLM)
    finetune_attention_modules = True,  # Fine-tune các lớp attention
    finetune_mlp_modules       = True,  # Fine-tune các lớp MLP

    r = 16,                            # Độ rank của LoRA
    lora_alpha = 16,                   # Alpha scale
    lora_dropout = 0,
    bias = "none",
    random_state = 3407,
    use_rslora = False,
    target_modules = "all-linear",     # Áp dụng lên toàn bộ linear layers để chất lượng tối ưu
)

# %%
# Áp dụng template chat chuẩn của Gemma-4
from unsloth import get_chat_template

processor = get_chat_template(
    processor,
    chat_template = "gemma-4" # model lớn thì thêm gemma-4-thinking
)

# %% [markdown]
# ## 3. Cấu hình Callback Giám sát gửi thông báo về Discord
#
# Chúng ta định nghĩa lớp callback tùy chỉnh `DiscordWebhookCallback` kế thừa từ `TrainerCallback` của Hugging Face. Khi Trainer chạy qua các mốc bắt đầu, log loss định kỳ và kết thúc, tin nhắn sẽ tự động bắn về kênh Discord thông qua Webhook URL.

# %%
import requests
from transformers import TrainerCallback

class DiscordWebhookCallback(TrainerCallback):
    def __init__(self, webhook_url, model_name):
        self.webhook_url = webhook_url
        self.model_name = model_name

    def send_discord_message(self, content):
        if not self.webhook_url or "discord.com/api/webhooks" not in self.webhook_url:
            print("⚠️ Discord Webhook chưa được thiết lập chính xác hoặc bị bỏ trống. Bỏ qua gửi thông báo!")
            return
        try:
            payload = {"content": content}
            response = requests.post(self.webhook_url, json=payload)
            if response.status_code != 204:
                print(f"⚠️ Gửi thông báo đến Discord thất bại: HTTP {response.status_code}")
        except Exception as e:
            print(f"❌ Lỗi kết nối khi gửi Discord: {e}")

    def on_train_begin(self, args, state, control, **kwargs):
        self.send_discord_message(
            f"🚀 **[BẮT ĐẦU TRAINING]**\n"
            f"• **Mô hình:** `{self.model_name}`\n"
            f"• **Tham số:** `lr={args.learning_rate}`, `steps={args.max_steps}`, `batch_size={args.per_device_train_batch_size}`\n"
            f"• **Platform:** Comet ML Project: `gemma4-medical-vqa`"
        )

    def on_log(self, args, state, control, logs=None, **kwargs):
        # Định kỳ mỗi 10 steps sẽ gửi thông báo cập nhật một lần tránh bị Discord rate-limit
        if logs and "loss" in logs:
            step = state.global_step
            loss = logs["loss"]
            epoch = logs.get("epoch", 0.0)
            lr = logs.get("learning_rate", 0.0)
            if step % 10 == 0 or step == args.max_steps:
                self.send_discord_message(
                    f"📈 **[TIẾN TRÌNH TRAINING]** Step `{step}`/`{args.max_steps}` (Epoch {epoch:.2f})\n"
                    f"• **Loss:** `{loss:.4f}`\n"
                    f"• **Learning Rate:** `{lr:.2e}`"
                )

    def on_train_end(self, args, state, control, **kwargs):
        self.send_discord_message(
            f"🎉 **[TRAINING HOÀN TẤT]**\n• Mô hình `{self.model_name}` đã train thành công với `{state.global_step}` steps!"
        )

# %% [markdown]
# ## 4. Huấn luyện Mô hình (Fine-Tuning Loop với Checkpoint)
#
# Sử dụng `SFTTrainer` từ TRL cùng collator dữ liệu vision chuyên biệt `UnslothVisionDataCollator` của Unsloth để bắt đầu training. Thiết lập lưu checkpoint định kỳ giúp khôi phục phiên huấn luyện nếu xảy ra sự cố.

# %%
from unsloth.trainer import UnslothVisionDataCollator
from trl import SFTTrainer, SFTConfig

# Khởi tạo callback Discord gửi webhook
discord_cb = DiscordWebhookCallback(webhook_url=DISCORD_WEBHOOK_URL, model_name=model_name)

trainer = SFTTrainer(
    model = model,
    train_dataset = converted_train_dataset,
    processing_class = processor.tokenizer,
    data_collator=UnslothVisionDataCollator(
        model,
        processor,
        resize=(512, 512),
    ),
    callbacks = [discord_cb],
    args = SFTConfig(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 4,
        max_grad_norm = 0.3,
        
        # Đã sửa: dùng warmup_steps thay vì warmup_ratio để xóa cảnh báo v5.2
        warmup_steps = 2, 
        
        learning_rate = 2e-4,
        
        # --- CẤU HÌNH CHẠY FULL TOÀN BỘ TẬP DỮ LIỆU ---
        num_train_epochs = 1,     # Chạy hết sạch 1 lượt dataset thay vì dừng ở step 60
        logging_steps = 10,       # Cứ 10 steps mới log một lần để đỡ spam Discord/Comet
        
        # --- CẤU HÌNH CHECKPOINT CỤC BỘ --- 
        save_strategy = "steps",
        save_steps = 50,          # Tăng lên 50 steps mới lưu checkpoint một lần cho nhẹ đĩa
        save_total_limit = 2,     # Giữ tối đa 2 checkpoint mới nhất tránh đầy dung lượng Kaggle
        
        # --- TỰ ĐỘNG SYNC CHECKPOINT LÊN HUGGING FACE HUB ---
        push_to_hub = True,
        hub_model_id = "HoangVuSnape/gemma_4_lora", 
        hub_strategy = "checkpoint",                        # Tự động đồng bộ hóa các checkpoint lên HF
        hub_token = os.environ.get("HF_TOKEN"),
        output_dir = "gemma_4_lora_project",                # Tên thư mục cục bộ trùng tên repo trên HF
        
        optim = "adamw_8bit",
        weight_decay = 0.001,
        lr_scheduler_type = "cosine",
        seed = 3407,
        
        # Đã sửa: Ghi chuẩn comet_ml để xóa lỗi ValueError
        report_to = "comet_ml",    

        # Đã sửa: Ghim cứng loss_type="nll" tương thích Unsloth để xóa FutureWarning của TRL 1.7
        loss_type = "nll",

        # Các thiết lập bắt buộc phục vụ vision fine-tuning:
        remove_unused_columns = False,
        dataset_text_field = "",
        dataset_kwargs = {"skip_prepare_dataset": True},
        max_length = 2048,
    )
)

# %%
# Kiểm tra bộ nhớ VRAM của GPU hiện hành trước khi chạy
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"🖥️ Thiết bị GPU: {gpu_stats.name} | Dung lượng RAM tối đa: {max_memory} GB.")
print(f"📊 VRAM đã chiếm dụng trước khi train: {start_gpu_memory} GB.")
# Out:
# 🖥️ Thiết bị GPU: Tesla T4 | Dung lượng RAM tối đa: 14.562 GB.
# 📊 VRAM đã chiếm dụng trước khi train: 8.518 GB.

# %%
# Bắt đầu huấn luyện mô hình
# Để tiếp tục huấn luyện (resume) từ checkpoint gần nhất, uncomment dòng dưới đây:
# trainer_stats = trainer.train(resume_from_checkpoint = True)

# Huấn luyện bình thường từ đầu:
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,793 | Num Epochs = 1 | Total steps = 449
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 4 x 1) = 4
#  "-____-"     Trainable parameters = 29,859,840 of 5,153,037,856 (0.58% trained)
#     <div>
#
#       <progress value='449' max='449' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [449/449 39:09, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.419506</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.369279</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.378554</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.365825</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.373470</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.314275</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.357661</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.303901</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.309720</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.305106</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.292221</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.297464</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.271359</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.392175</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.291914</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.374756</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.382759</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.306833</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.346380</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.365901</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.310724</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.311452</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.294430</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.281108</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.299284</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.327073</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.296213</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.274799</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.318623</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.284601</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.303406</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.327521</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.309913</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.301208</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.262009</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.347672</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.301147</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.259982</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.286419</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.306409</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.290505</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.289759</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.258698</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.281211</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Restored added_tokens_decoder metadata in gemma_4_lora_project/checkpoint-150/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in gemma_4_lora_project/checkpoint-200/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in gemma_4_lora_project/checkpoint-250/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in gemma_4_lora_project/checkpoint-300/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in gemma_4_lora_project/checkpoint-350/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in gemma_4_lora_project/checkpoint-400/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in gemma_4_lora_project/checkpoint-449/tokenizer_config.json.

# %% [markdown]
# ## 5. Kiểm thử Mô hình & Lưu trữ LoRA Weights (Inference & Save)
#
# Sau khi train xong, chúng ta chạy thử dự đoán trên một ảnh X-ray y tế mẫu bất kỳ và lưu lại các file adapter LoRA đã được tối ưu lên Hugging Face Hub (online).

# %%
import random

# Chọn 1 mẫu bất kỳ trong dataset test để kiểm tra
test_sample = test_dataset[random.randint(0, len(test_dataset)-1)]
image = test_sample["image"].convert("RGB")
question = test_sample["question"]
gold_answer = test_sample["answer"]

messages = [
    {
        "role": "user",
        "content": [
            {"type": "image"},
            {"type": "text", "text": question}
        ]
    }
]

input_text = processor.apply_chat_template(messages, add_generation_prompt = True)
inputs = processor(
    image,
    input_text,
    add_special_tokens = False,
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(processor.tokenizer, skip_prompt = True)

print("❓ Câu hỏi (Question):")
print(question)
print("\n📝 Bệnh án gốc (Ground Truth):")
print(gold_answer)
print("\n📝 Mô tả dự đoán từ mô hình sau Fine-tuning:")
_ = model.generate(
    **inputs, 
    streamer = text_streamer, 
    max_new_tokens = 128,
    use_cache = True,
    temperature = 1.0,
    top_p = 0.95,
    top_k = 64
)
# Out:
# ❓ Câu hỏi (Question):
# what are the bright white structures, almost forming an x"?"
#
# 📝 Bệnh án gốc (Ground Truth):
# lateral ventricles
#
# 📝 Mô tả dự đoán từ mô hình sau Fine-tuning:
# The bright white structures are likely areas of edema or inflammation in the brain.<turn|>

# %%
import random
import torch
import matplotlib.pyplot as plt

def infer_one_sample(model, processor, sample, device="cuda"):
    image = sample["image"].convert("RGB")
    question = sample["question"]
    gold_answer = sample["answer"].strip()

    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image"},
                {
                    "type": "text",
                    "text": (
                        "Answer the medical VQA question using a short answer only. "
                        "Do not explain. Do not guess pathology if the question asks for anatomy. "
                        f"Question: {question}"
                    ),
                },
            ],
        }
    ]

    input_text = processor.apply_chat_template(
        messages,
        add_generation_prompt=True,
    )

    inputs = processor(
        image,
        input_text,
        add_special_tokens=False,
        return_tensors="pt",
    ).to(device)

    with torch.inference_mode():
        outputs = model.generate(
            **inputs,
            max_new_tokens=16,
            do_sample=False,
            use_cache=True,
            eos_token_id=processor.tokenizer.eos_token_id,
            pad_token_id=processor.tokenizer.eos_token_id,
        )

    generated_tokens = outputs[0][inputs["input_ids"].shape[1]:]
    pred_answer = processor.tokenizer.decode(
        generated_tokens,
        skip_special_tokens=True
    ).strip()

    plt.figure(figsize=(5, 5))
    plt.imshow(image)
    plt.axis("off")
    plt.title("Test image")
    plt.show()

    print("❓ Question:")
    print(question)

    print("\n📝 Ground Truth:")
    print(gold_answer)

    print("\n🤖 Prediction:")
    print(pred_answer)

    print("\n-----====-----")

    return {
        "question": question,
        "ground_truth": gold_answer,
        "prediction": pred_answer,
    }


def infer_random_samples(model, processor, dataset, num_samples=5, device="cuda", seed=None):
    if seed is not None:
        random.seed(seed)

    num_samples = min(num_samples, len(dataset))
    indices = random.sample(range(len(dataset)), num_samples)

    results = []
    for i, idx in enumerate(indices, 1):
        print(f"\n========== Sample {i}/{num_samples} ==========\n")
        sample = dataset[idx]
        result = infer_one_sample(model, processor, sample, device=device)
        results.append(result)

    return results

# %%
results = infer_random_samples(
    model=model,
    processor=processor,
    dataset=test_dataset,
    num_samples=5,
    device="cuda",
    seed=42
)
# Out:
# ========== Sample 1/5 ==========
# ❓ Question:
# what image modality is used?
#
# 📝 Ground Truth:
# ct
#
# 🤖 Prediction:
# CT
#
# -----====-----
#
# ========== Sample 2/5 ==========
# ❓ Question:
# is the small bowel appropriately identified with gi contrast?
#
# 📝 Ground Truth:
# yes
#
# 🤖 Prediction:
# Yes
#
# -----====-----
#
# ========== Sample 3/5 ==========
# ❓ Question:
# what is this lucency amid densities in the right lung?
#
# 📝 Ground Truth:
# the right bronchus
#
# 🤖 Prediction:
# Infiltrate
#
# -----====-----
#
# ========== Sample 4/5 ==========
# ❓ Question:
# how would you describe the spleen abnormality
#
# 📝 Ground Truth:
# hypodense lesion
#
# 🤖 Prediction:
# Heterogeneous enhancement
#
# -----====-----
#
# ========== Sample 5/5 ==========
# ❓ Question:
# is this a t1 weighted mri?
#
# 📝 Ground Truth:
# no
#
# 🤖 Prediction:
# No
#
# -----====-----

# %%
# 1. Lưu adapter LoRA xuống thư mục cục bộ
model.save_pretrained("gemma_4_lora")
processor.save_pretrained("gemma_4_lora")
print("✅ Lưu LoRA adapter thành công vào thư mục 'gemma_4_lora'!")

# 2. Đẩy model lên Hugging Face Hub (online) sử dụng HF Token đã nạp ở đầu notebook
if os.environ.get("HF_TOKEN") and os.environ.get("HF_TOKEN") != "YOUR_HF_TOKEN":
    try:
        # Vui lòng thay thế 'username/model_name' bằng tài khoản HF thực tế của bạn
        # model.push_to_hub("your_name/gemma_4_lora", token = os.environ["HF_TOKEN"])
        # processor.push_to_hub("your_name/gemma_4_lora", token = os.environ["HF_TOKEN"])
        print("🤗 Đã sẵn sàng các lệnh push_to_hub! (Uncomment các lệnh trên để đẩy online)")
    except Exception as e:
        print(f"⚠️ Gặp lỗi khi đẩy model lên HF Hub: {e}")
else:
    print("⚠️ Không tìm thấy HF_TOKEN hợp lệ. Bỏ qua việc upload lên Hugging Face Hub.")
# Out:
# Unsloth: Restored added_tokens_decoder metadata in gemma_4_lora/tokenizer_config.json.
# ✅ Lưu LoRA adapter thành công vào thư mục 'gemma_4_lora'!
# 🤗 Đã sẵn sàng các lệnh push_to_hub! (Uncomment các lệnh trên để đẩy online)
